# %%
# !pip install pyarrow

# %%
import pyarrow

print(pyarrow.__version__)
# Out:
# 23.0.0

# %%
import pandas as pd

events = pd.read_parquet("data/intermediate/events_labeled.parquet")
print(len(events))
# Out:
# 1058672

# %%
print(events.head(5))
# Out:
#   ticker                                           headline  \
# 0      A            Stocks That Hit 52-Week Highs On Friday
# 1      A         Stocks That Hit 52-Week Highs On Wednesday
# 2      A                      71 Biggest Movers From Friday
# 3      A       46 Stocks Moving In Friday's Mid-Day Session
# 4      A  B of A Securities Maintains Neutral on Agilent...
#
#               published_utc              published_et entry_date  horizon  \
# 0 2020-06-05 14:30:00+00:00 2020-06-05 10:30:00-04:00 2020-06-08        1
# 1 2020-06-03 14:45:00+00:00 2020-06-03 10:45:00-04:00 2020-06-04        1
# 2 2020-05-26 08:30:00+00:00 2020-05-26 04:30:00-04:00 2020-05-27        1
# 3 2020-05-22 16:45:00+00:00 2020-05-22 12:45:00-04:00 2020-05-26        1
# 4 2020-05-22 15:38:00+00:00 2020-05-22 11:38:00-04:00 2020-05-26        1
#
#    exit_date  entry_close  exit_close   spy_entry    spy_exit       ret  \
# 0 2020-06-09    86.778976   86.279175  297.910217  295.688782 -0.005759
# ...

# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu130
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.9 GB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 GB 67.6 MB/s eta 0:00:28
#     --------------------------------------- 0.0/1.9 GB 70.7 MB/s eta 0:00:27
#     --------------------------------------- 0.0/1.9 GB 69.4 MB/s eta 0:00:27
#    - -------------------------------------- 0.1/1.9 GB 64.7 MB/s eta 0:00:29
#    - -------------------------------------- 0.1/1.9 GB 58.6 MB/s eta 0:00:31
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
